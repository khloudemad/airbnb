# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # read the file

# %%
df = pd.read_csv(r'C:\Users\IShop\Desktop\listings.csv')
df
# Out:
#                        id                                       listing_url  \
# 0                  108061               https://www.airbnb.com/rooms/108061
# 1                  155305               https://www.airbnb.com/rooms/155305
# 2                  156805               https://www.airbnb.com/rooms/156805
# 3                  156926               https://www.airbnb.com/rooms/156926
# 4                  197263               https://www.airbnb.com/rooms/197263
# ...                   ...                                               ...
# 3324  1042298260025618001  https://www.airbnb.com/rooms/1042298260025618001
# 3325  1042809291090816535  https://www.airbnb.com/rooms/1042809291090816535
# 3326  1045930442276845410  https://www.airbnb.com/rooms/1045930442276845410
# 3327  1046995843173939904  https://www.airbnb.com/rooms/1046995843173939904
# 3328  1046996332735534663  https://www.airbnb.com/rooms/1046996332735534663
#
#            scrape_id last_scraped           source  \
# 0     20231218164947   2023-12-18  previous scrape
# 1     20231218164947   2023-12-27      city scrape
# 2     20231218164947   2023-12-18      city scrape
# 3     20231218164947   2023-12-18      city scrape
# 4     20231218164947   2023-12-18      city scrape
# ...              ...          ...              ...
# 3324  20231218164947   2023-12-18      city scrape
# 3325  20231218164947   2023-12-18      city scrape
# 3326  20231218164947   2023-12-18      city scrape
# 3327  20231218164947   2023-12-18      city scrape
# 3328  20231218164947   2023-12-18      city scrape
#
#                                                    name  description  \
# 0     Rental unit in Asheville · ★4.52 · 1 bedroom ·...          NaN
# 1     Guesthouse in Asheville · ★4.60 · 1 bedroom · ...          NaN
# 2     Home in Asheville · ★4.52 · 1 bedroom · 1 bed ...          NaN
# 3     Hostel in Asheville · ★4.70 · 1 bedroom · 6 be...          NaN
# 4     Home in Asheville · ★4.96 · 1 bedroom · 1 bed ...          NaN
# ...                                                 ...          ...
# 3324  Rental unit in Asheville · ★New · 1 bedroom · ...          NaN
# 3325  Home in Asheville · ★New · 2 bedrooms · 3 beds...          NaN
# 3326  Home in Fletcher · ★New · 3 bedrooms · 4 beds ...          NaN
# 3327  Rental unit in Asheville · ★New · 1 bedroom · ...          NaN
# 3328  Rental unit in Arden · ★New · 1 bedroom · 1 be...          NaN
#
#                                   neighborhood_overview  \
# 0     I love my neighborhood! Its friendly, easy-goi...
# 1     We are within easy walk of pubs, breweries, mu...
# 2     Easy walk to pubs, cafes, bakery, breweries, l...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3324  Wilshire Park in west Asheville, great neighbo...
# 3325                                                NaN
# 3326                                                NaN
# 3327  Cute neighborhood very close to the esteemed B...
# 3328                                                NaN
#
#                                             picture_url    host_id  ...  \
# 0     https://a0.muscache.com/pictures/miso/Hosting-...     320564  ...
# 1     https://a0.muscache.com/pictures/8880711/cf38d...     746673  ...
# 2     https://a0.muscache.com/pictures/23447d55-fa7e...     746673  ...
# 3     https://a0.muscache.com/pictures/5fa7178e-c514...     746673  ...
# 4     https://a0.muscache.com/pictures/miso/Hosting-...     961396  ...
# ...                                                 ...        ...  ...
# 3324  https://a0.muscache.com/pictures/miso/Hosting-...   17346283  ...
# 3325  https://a0.muscache.com/pictures/miso/Hosting-...   56276837  ...
# 3326  https://a0.muscache.com/pictures/hosting/Hosti...  473818786  ...
# 3327  https://a0.muscache.com/pictures/hosting/Hosti...    5025894  ...
# 3328  https://a0.muscache.com/pictures/miso/Hosting-...  251085740  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                           4.80                   4.84                4.49
# 1                           4.74                   4.92                4.56
# 2                           4.61                   4.84                4.46
# 3                           4.77                   4.78                4.78
# 4                           4.94                   4.85                4.99
# ...                          ...                    ...                 ...
# 3324                         NaN                    NaN                 NaN
# 3325                         NaN                    NaN                 NaN
# 3326                         NaN                    NaN                 NaN
# 3327                         NaN                    NaN                 NaN
# 3328                         NaN                    NaN                 NaN
#
#      license instant_bookable calculated_host_listings_count  \
# 0        NaN                f                              2
# 1        NaN                f                              8
# 2        NaN                t                              8
# 3        NaN                t                              8
# 4        NaN                f                              2
# ...      ...              ...                            ...
# 3324     NaN                t                              1
# 3325     NaN                f                              1
# 3326     NaN                f                              2
# 3327     NaN                f                              1
# 3328     NaN                f                              1
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              2
# 1                                              2
# 2                                              2
# 3                                              2
# 4                                              1
# ...                                          ...
# 3324                                           1
# 3325                                           1
# 3326                                           2
# 3327                                           0
# 3328                                           1
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               0
# 1                                               2
# 2                                               2
# 3                                               2
# 4                                               1
# ...                                           ...
# 3324                                            0
# 3325                                            0
# 3326                                            0
# 3327                                            1
# 3328                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0              0.62
# 1                                              4              2.73
# 2                                              4              0.45
# 3                                              4              2.25
# 4                                              0              0.56
# ...                                          ...               ...
# 3324                                           0               NaN
# 3325                                           0               NaN
# 3326                                           0               NaN
# 3327                                           0               NaN
# 3328                                           0               NaN
#
# [3329 rows x 75 columns]

# %%
df.shape
# Out:
# (3329, 75)

# %%
df.isna().sum()
# Out:
# id                                                0
# listing_url                                       0
# scrape_id                                         0
# last_scraped                                      0
# source                                            0
#                                                ...
# calculated_host_listings_count                    0
# calculated_host_listings_count_entire_homes       0
# calculated_host_listings_count_private_rooms      0
# calculated_host_listings_count_shared_rooms       0
# reviews_per_month                               220
# Length: 75, dtype: int64

# %% [markdown]
# # handel missing values

# %%
df=df.drop(columns=['listing_url','scrape_id','description','neighborhood_overview','license','host_about','neighbourhood_group_cleansed','bathrooms','amenities','bedrooms'])
df
# Out:
#                        id last_scraped           source  \
# 0                  108061   2023-12-18  previous scrape
# 1                  155305   2023-12-27      city scrape
# 2                  156805   2023-12-18      city scrape
# 3                  156926   2023-12-18      city scrape
# 4                  197263   2023-12-18      city scrape
# ...                   ...          ...              ...
# 3324  1042298260025618001   2023-12-18      city scrape
# 3325  1042809291090816535   2023-12-18      city scrape
# 3326  1045930442276845410   2023-12-18      city scrape
# 3327  1046995843173939904   2023-12-18      city scrape
# 3328  1046996332735534663   2023-12-18      city scrape
#
#                                                    name  \
# 0     Rental unit in Asheville · ★4.52 · 1 bedroom ·...
# 1     Guesthouse in Asheville · ★4.60 · 1 bedroom · ...
# 2     Home in Asheville · ★4.52 · 1 bedroom · 1 bed ...
# 3     Hostel in Asheville · ★4.70 · 1 bedroom · 6 be...
# 4     Home in Asheville · ★4.96 · 1 bedroom · 1 bed ...
# ...                                                 ...
# 3324  Rental unit in Asheville · ★New · 1 bedroom · ...
# 3325  Home in Asheville · ★New · 2 bedrooms · 3 beds...
# 3326  Home in Fletcher · ★New · 3 bedrooms · 4 beds ...
# 3327  Rental unit in Asheville · ★New · 1 bedroom · ...
# 3328  Rental unit in Arden · ★New · 1 bedroom · 1 be...
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/miso/Hosting-...     320564
# 1     https://a0.muscache.com/pictures/8880711/cf38d...     746673
# 2     https://a0.muscache.com/pictures/23447d55-fa7e...     746673
# 3     https://a0.muscache.com/pictures/5fa7178e-c514...     746673
# 4     https://a0.muscache.com/pictures/miso/Hosting-...     961396
# ...                                                 ...        ...
# 3324  https://a0.muscache.com/pictures/miso/Hosting-...   17346283
# 3325  https://a0.muscache.com/pictures/miso/Hosting-...   56276837
# 3326  https://a0.muscache.com/pictures/hosting/Hosti...  473818786
# 3327  https://a0.muscache.com/pictures/hosting/Hosti...    5025894
# 3328  https://a0.muscache.com/pictures/miso/Hosting-...  251085740
#
#                                          host_url host_name  host_since  \
# 0        https://www.airbnb.com/users/show/320564      Lisa  2010-12-16
# 1        https://www.airbnb.com/users/show/746673   BonPaul  2011-06-26
# 2        https://www.airbnb.com/users/show/746673   BonPaul  2011-06-26
# 3        https://www.airbnb.com/users/show/746673   BonPaul  2011-06-26
# 4        https://www.airbnb.com/users/show/961396      Timo  2011-08-12
# ...                                           ...       ...         ...
# 3324   https://www.airbnb.com/users/show/17346283      Gary  2014-06-27
# 3325   https://www.airbnb.com/users/show/56276837      Lisa  2016-01-26
# 3326  https://www.airbnb.com/users/show/473818786      Thuy  2022-08-07
# 3327    https://www.airbnb.com/users/show/5025894     Jules  2013-02-09
# 3328  https://www.airbnb.com/users/show/251085740  Clifford  2019-03-25
#
#       host_location  ... review_scores_checkin review_scores_communication  \
# 0     Asheville, NC  ...                  4.86                        4.80
# 1     Asheville, NC  ...                  4.84                        4.74
# 2     Asheville, NC  ...                  4.76                        4.61
# 3     Asheville, NC  ...                  4.83                        4.77
# 4     Asheville, NC  ...                  4.96                        4.94
# ...             ...  ...                   ...                         ...
# 3324  Asheville, NC  ...                   NaN                         NaN
# 3325    Raleigh, NC  ...                   NaN                         NaN
# 3326            NaN  ...                   NaN                         NaN
# 3327  Asheville, NC  ...                   NaN                         NaN
# 3328     Marvin, NC  ...                   NaN                         NaN
#
#      review_scores_location review_scores_value instant_bookable  \
# 0                      4.84                4.49                f
# 1                      4.92                4.56                f
# 2                      4.84                4.46                t
# 3                      4.78                4.78                t
# 4                      4.85                4.99                f
# ...                     ...                 ...              ...
# 3324                    NaN                 NaN                t
# 3325                    NaN                 NaN                f
# 3326                    NaN                 NaN                f
# 3327                    NaN                 NaN                f
# 3328                    NaN                 NaN                f
#
#      calculated_host_listings_count  \
# 0                                 2
# 1                                 8
# 2                                 8
# 3                                 8
# 4                                 2
# ...                             ...
# 3324                              1
# 3325                              1
# 3326                              2
# 3327                              1
# 3328                              1
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              2
# 1                                              2
# 2                                              2
# 3                                              2
# 4                                              1
# ...                                          ...
# 3324                                           1
# 3325                                           1
# 3326                                           2
# 3327                                           0
# 3328                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                2
# 2                                                2
# 3                                                2
# 4                                                1
# ...                                            ...
# 3324                                             0
# 3325                                             0
# 3326                                             0
# 3327                                             1
# 3328                                             0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.62
# 1                                               4              2.73
# 2                                               4              0.45
# 3                                               4              2.25
# 4                                               0              0.56
# ...                                           ...               ...
# 3324                                            0               NaN
# 3325                                            0               NaN
# 3326                                            0               NaN
# 3327                                            0               NaN
# 3328                                            0               NaN
#
# [3329 rows x 65 columns]

# %%
df.describe()
# Out:
#                  id       host_id  host_listings_count  \
# count  3.110000e+03  3.110000e+03          3110.000000
# mean   2.841003e+17  1.502084e+08            49.866238
# std    3.903544e+17  1.502610e+08           214.336291
# min    1.553050e+05  4.134000e+03             1.000000
# 25%    2.879295e+07  2.600251e+07             1.000000
# 50%    4.801796e+07  9.989858e+07             2.000000
# 75%    6.924365e+17  2.180855e+08             7.000000
# max    1.046996e+18  5.472655e+08          1645.000000
#
#        host_total_listings_count  neighbourhood_cleansed     latitude  \
# count                3110.000000             3110.000000  3110.000000
# mean                   73.971383            28792.366559    35.576201
# std                   340.515744               30.701072     0.049500
# min                     1.000000            28704.000000    35.421950
# 25%                     1.000000            28801.000000    35.558793
# 50%                     3.000000            28804.000000    35.587290
# 75%                     8.000000            28806.000000    35.606426
# max                  2577.000000            28806.000000    35.658070
#
#          longitude  accommodates         beds  minimum_nights  ...  \
# count  3110.000000   3110.000000  3082.000000     3110.000000  ...
# mean    -82.557760      4.675884     2.614212        5.055949  ...
# std       0.048513      3.001945     1.943397       10.698570  ...
# min     -82.690110      1.000000     1.000000        1.000000  ...
# 25%     -82.592250      2.000000     1.000000        1.000000  ...
# 50%     -82.557183      4.000000     2.000000        2.000000  ...
# 75%     -82.519495      6.000000     3.000000        2.000000  ...
# max     -82.457480     16.000000    20.000000      180.000000  ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                2927.000000             2926.00000
# mean                    4.896611                4.94596
# std                     0.196502                0.12517
# min                     1.000000                1.00000
# 25%                     4.870000                4.94000
# 50%                     4.950000                4.98000
# 75%                     5.000000                5.00000
# max                     5.000000                5.00000
#
#        review_scores_communication  review_scores_location  \
# count                  2927.000000             2927.000000
# mean                      4.931794                4.877714
# std                       0.171550                0.144622
# min                       1.000000                2.500000
# 25%                       4.930000                4.840000
# 50%                       4.980000                4.910000
# 75%                       5.000000                4.970000
# max                       5.000000                5.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count          2927.000000                     3110.000000
# mean              4.816204                        9.327974
# std               0.228576                       22.722553
# min               1.000000                        1.000000
# 25%               4.760000                        1.000000
# 50%               4.860000                        2.000000
# 75%               4.940000                        4.000000
# max               5.000000                      113.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  3110.000000
# mean                                      8.936656
# std                                      22.799055
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       3.000000
# max                                     113.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   3110.000000
# mean                                       0.338264
# std                                        1.158707
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        9.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  3110.000000        2926.000000
# mean                                      0.015756           2.567105
# std                                       0.227017           2.101894
# min                                       0.000000           0.010000
# 25%                                       0.000000           1.000000
# 50%                                       0.000000           2.080000
# 75%                                       0.000000           3.580000
# max                                       4.000000          19.070000
#
# [8 rows x 37 columns]

# %% [markdown]
# # visiualization

# %%
calc_host_list=df[['calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms']]
sns.barplot(calc_host_list)
plt.title('host listings')
plt.xlabel('type of listing')
plt.ylabel('number of listing')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df['latitude'],y=df['longitude'],hue=df['review_scores_location'],palette='coolwarm')
plt.show()

# %%
availability_data = df[['availability_30', 'availability_60', 'availability_90', 'availability_365']]
availability_data_melted = availability_data.melt(var_name='Availability Period', value_name='Number of Available Days')
plt.figure(figsize=(10, 6))
sns.barplot(data=availability_data_melted, x='Availability Period', y='Number of Available Days', ci=None)
plt.title('Availability Distribution for Different Time Periods')
plt.xlabel('Availability Period')
plt.ylabel('Number of Available Days')
plt.show()
# Out:
# C:\Users\IShop\AppData\Local\Temp\ipykernel_14644\4213775682.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=availability_data_melted, x='Availability Period', y='Number of Available Days', ci=None)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='property_type', order=df['property_type'].value_counts().index)
plt.title('Distribution of Property Types')
plt.xlabel('Property Type')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right') 
plt.tight_layout()  
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(20, 15))
rev_by_property_type=df.groupby('property_type')['reviews_per_month'].mean().sort_values(ascending=False)
rev_by_location=df.groupby('neighbourhood')['reviews_per_month'].mean().sort_values(ascending=False)
sns.barplot(x=rev_by_property_type.values, y=price_by_property_type.index, ax=axes[0], palette='viridis')
axes[0].set_title('Average reviews_per_month by Property Type')
axes[0].set_xlabel('Average reviews_per_month (USD)')
axes[0].set_ylabel('Property Type')
sns.barplot(x=rev_by_location.values, y=price_by_location.index, ax=axes[1], palette='viridis')
axes[1].set_title('Average reviews_per_month by Neighborhood')
axes[1].set_xlabel('Average reviews_per_month (USD)')
axes[1].set_ylabel('Neighborhood')
plt.tight_layout()
plt.show()
